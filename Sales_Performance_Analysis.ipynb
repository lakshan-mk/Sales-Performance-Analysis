# %% [markdown]
# # **Project: Sales Performance Analysis for QuantumLeap Analytics**
#
# Welcome to the QuantumLeap Analytics sales performance deep-dive! In this project, you will step into the role of a Sales Operations Analyst at a thriving B2B technology company. You've been handed a raw, unfiltered dataset containing three years of sales transactions. Your mission is to cut through the noise, clean the data, and uncover the critical insights that will shape the company's sales strategy for the next year.
#
# ---
#
# ## **1. Domain Explanation: The World of Sales & Business Analytics**
#
# Before diving into the data, it's crucial to understand the business context. Sales is the engine of any commercial enterprise, and data analytics is the navigation system that ensures this engine is running efficiently and in the right direction.
#
# ### **The Business Model: How Sales Operations Work**
#
# Modern sales organizations, especially in the B2B (Business-to-Business) sector, operate on a structured process designed to guide potential clients from initial awareness to a final purchase. This process is often visualized as a **Sales Funnel** or **Sales Pipeline**.
#
# 1.  **Lead Generation:** This is the top of the funnel. The company generates leads (potential customers) through various channels like marketing campaigns (`Web`, `Organic`), networking (`Trade Show`), existing relationships (`Referral`), or direct outreach (`Cold Call`).
# 2.  **Qualification:** The sales team qualifies these leads to determine if they are a good fit for the product—do they have the need, the budget, and the authority to make a purchase?
# 3.  **Proposal & Negotiation:** For qualified leads, sales representatives (`Sales Reps`) present a tailored proposal. This stage often involves negotiations on price, features, and contract terms. Discounts may be offered to close the deal.
# 4.  **Closing:** The deal is won, and the prospect becomes a customer. The order is processed, and the logistics of fulfillment begin.
# 5.  **Retention & Upselling:** The relationship doesn't end at the sale. Successful companies focus on retaining customers and selling them additional products or services over time.
#
# This entire process is managed through different **Sales Channels**. A `Direct` channel involves a sales rep engaging directly with the client. An `Online` channel is self-serve, typically for smaller transactions. `Reseller` or `Partner` channels involve third parties selling the company's products.
#
# ### **The Importance of Data in Sales**
#
# In a competitive market, relying on intuition or "gut feelings" is a recipe for failure. Sales data is the source of truth. It provides an objective view of what's working and what isn't. By analyzing transaction data, a company can:
# * Identify its most profitable products and customer segments.
# * Recognize its top-performing (and underperforming) sales representatives.
# * Optimize pricing and discount strategies.
# * Forecast future revenue with greater accuracy.
# * Understand which sales channels and marketing efforts provide the best return on investment.
#
# Without data analysis, a sales organization cannot effectively scale, adapt to market changes, or hold its teams accountable for their performance.
#
# ### **Key Performance Indicators (KPIs) in Sales**
#
# To measure success, sales leaders constantly monitor a set of critical KPIs:
#
# * **Sales Revenue:** The most fundamental metric—the total amount of money generated from sales. This can be broken down by region, product, or sales rep.
# * **Quota Attainment:** The percentage of the sales team that is achieving their assigned sales quota (target). This is a key indicator of the team's overall health.
# * **Win Rate:** The percentage of qualified leads that are successfully converted into customers. A low win rate might indicate problems with the product, pricing, or sales process.
# * **Sales Cycle Length:** The average amount of time it takes to close a deal, from initial contact to the final signature. A long sales cycle can increase costs and risk losing the deal to a competitor.
# * **Average Deal Size:** The average revenue generated from each closed deal. A key goal is often to increase this metric through upselling or focusing on larger clients.
# * **Lead Conversion Rate:** The percentage of leads from a particular source that become qualified prospects. This helps measure the quality of leads generated by marketing.
#
# ### **Common Challenges & The Role of Data Analysis**
#
# Sales organizations face numerous challenges that data analysis can directly address:
#
# * **Challenge: Inaccurate Forecasting.** Predicting future sales is notoriously difficult but essential for financial planning.
#     * **Data Analysis Solution:** By analyzing historical sales data, seasonality, and the current sales pipeline, analysts can build statistical models to create more reliable sales forecasts.
# * **Challenge: Inconsistent Regional Performance.** Some sales regions may significantly outperform others.
#     * **Data Analysis Solution:** A deep-dive analysis can compare regions, identifying differences in product mix, discount strategies, or sales rep performance that explain the disparity.
# * **Challenge: Optimizing Discount Strategy.** Offering too many discounts can erode profit margins, while offering too few can lead to lost deals.
#     * **Data Analysis Solution:** By analyzing how discounts impact deal size and win rate, a company can identify the "sweet spot" for discounting that maximizes revenue without sacrificing profitability.
# * **Challenge: Identifying the Ideal Customer Profile (ICP).** Sales teams can waste significant effort chasing leads that are a poor fit.
#     * **Data Analysis Solution:** By analyzing the characteristics of the most profitable and loyal customers (industry, company size, location), analysts can build a data-driven ICP, allowing the sales and marketing teams to focus their efforts on the highest-potential leads.
#
# In short, data analysis empowers a sales organization to make smarter, faster, and more profitable decisions at every stage of the sales cycle.
#
# ---
#
# ## **2. Project Description & Business Understanding**
#
# Let's introduce our fictional company, "QuantumLeap Analytics," and the specific business problem you will be solving.
#
# ### **Company Background: QuantumLeap Analytics**
#
# **QuantumLeap Analytics** is a B2B SaaS (Software-as-a-Service) company that provides a cutting-edge business intelligence and data visualization platform. For the past five years, they have been a major player in the market, helping enterprise clients make sense of their complex data. The company operates globally, with major sales hubs in North America, EMEA (Europe, Middle East, and Africa), and APAC (Asia-Pacific). Their sales model is multi-channel, relying on a direct sales force for large enterprise deals, a reseller network for mid-market clients, and an online portal for smaller, self-serve subscriptions.
#
# ### **The Business Problem**
#
# The Head of Sales at QuantumLeap is facing a major strategic challenge. While overall company revenue has been growing, performance is **highly inconsistent** across different regions and sales channels. The North American `Direct` sales team is exceeding its quota, but the `Reseller` channel in APAC seems to be underperforming. The executive team is asking tough questions:
#
# * Are we investing in the right sales channels?
# * Are our discount strategies out of control in some regions?
# * Who are our top-performing sales reps, and what can we learn from them?
# * Which products are driving our growth, and which are lagging?
#
# The current sales reporting is basic and doesn't provide the deep insights needed to answer these questions. The raw transaction data has been extracted from the company's various systems, but it's a messy, unverified collection of records. You have been brought in as the lead analyst to clean this data, analyze it, and provide the Head of Sales with a clear, data-driven strategy for the upcoming year.
#
# ### **Project Goals & Objectives**
#
# Your analysis will be guided by these core business objectives:
#
# 1.  **Identify Top Performers:** Determine the top-performing sales reps, products, regions, and sales channels in terms of total revenue and profit.
# 2.  **Analyze Sales Funnel & Lead Sources:** Evaluate the effectiveness of different lead sources and identify which ones generate the most valuable customers.
# 3.  **Optimize Pricing & Discount Strategy:** Analyze the impact of discounts on sales volume and total price to recommend a more effective discounting policy.
# 4.  **Provide Actionable Recommendations:** Deliver a set of specific, data-backed recommendations to help QuantumLeap standardize its sales process and focus its resources on the most profitable activities.
#
# ### **The Data Analysis Lifecycle**
#
# You will follow a structured data analysis process:
#
# 1.  **Problem Definition:** Understanding QuantumLeap's strategic challenges and setting clear objectives. (Completed)
# 2.  **Data Collection:** You have been provided with a raw, imperfect dataset simulating a real-world data dump.
# 3.  **Data Cleaning & Preprocessing:** Your first critical task. You will tackle the messy dataset, fixing incorrect data types, handling missing values, resolving logical errors, and standardizing inconsistent data.
# 4.  **Feature Engineering & Selection:** You will create new, insightful columns from the existing data (e.g., calculating profit) to enable a deeper level of analysis.
# 5.  **Exploratory Data Analysis (EDA):** You will use statistics and visualizations to explore the data, uncover trends, and answer the key business questions.
# 6.  **Drawing Conclusions & Recommendations:** Finally, you will synthesize your findings into a coherent story and present actionable strategies to the Head of Sales.
#
# ---
#
# ## 3. **Dataset Column Explanation**
#
# Here is a breakdown of the 30 columns in your raw dataset. Understanding the data and its potential flaws is the first step to a successful analysis.
#
# | Column Name | Description | Potential Cleaning Issues |
# | :--- | :--- | :--- |
# | **OrderID** | Unique identifier for each order. | **Mixed data types** (integers and alphanumeric strings). |
# | **OrderDate** | The date the order was placed. | Needs to be converted to a proper datetime format. |
# | **Quantity** | The number of units sold. | **Contains text values** like 'One', 'Two', 'N/A'. Needs to be converted to a numeric type. |
# | **UnitPrice** | The price of a single unit. | **String format** with '$' and commas. Needs conversion to a numeric type. |
# | **TotalPrice** | The total price for the transaction. | **String format** with '$' and commas. **Contains logical errors** (doesn't always match `UnitPrice` * `Quantity`). |
# | **Discount_Applied**| The discount percentage applied. | **Contains missing values (NaN)**. |
# | **PaymentMethod** | The method used for payment. | Check for consistency. |
# | **ProductID** | A unique identifier for each product. | Should be unique per product. |
# | **ProductName** | The name of the product. | General text cleaning. |
# | **ProductCategory**| The main category of the product. | **Inconsistent naming and capitalization** (e.g., "Electronics", "ELEC"). |
# | **SKU** | Stock Keeping Unit for the product. | Check for any formatting issues. |
# | **CustomerID** | A unique identifier for each customer. | **Contains missing values (NaN)**, likely for guest checkouts. |
# | **CustomerName** | The name of the customer or company. | General text cleaning. |
# | **CustomerEmail** | The customer's email address. | Check for invalid formats. |
# | **CustomerPhone** | The customer's phone number. | Check for inconsistent formats. |
# | **BillingAddress** | The billing address for the order. | Long text field, may not be needed for high-level analysis. |
# | **ShippingCity** | The city where the order was shipped. | General text cleaning. |
# | **ShippingState** | The state/province where the order was shipped. | Check for consistency. |
# | **ShippingCountry** | The country where the order was shipped. | Check for consistency. |
# | **SalesRepID** | The ID of the sales representative. | **Contains missing values (NaN)**, especially for 'Online' channel sales. |
# | **SalesRepName** | The name of the sales representative. | Correspondingly has missing values. |
# | **Region** | The geographical region for the sale. | **Inconsistent naming** (e.g., "NA", "North America"). |
# | **SalesChannel** | The channel through which the sale was made. | Check for consistency. |
# | **LeadSource** | The source of the sales lead. | **Contains missing values (NaN)**. |
# | **OrderStatus** | The status of the order. | Important for filtering out 'Cancelled' or 'Returned' orders for revenue analysis. |
# | **ShippingDate** | The date the order was shipped. | **Contains logical errors** (can be before `OrderDate`). Needs to be a datetime object. |
# | **ShippingMethod** | The method of shipping. | Check for consistency. |
# | **WarehouseCode** | The code for the fulfillment warehouse. | Check for consistency. |
# | **Notes** | Optional free-text notes about the order. | Mostly unstructured text. |
# | **COGS_Percentage**| Cost of Goods Sold as a percentage of `TotalPrice`. | Key for calculating profit. Should be a numeric type. |
#
# ---

# %%
# Import the libraries which are required to work on this project
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Import the dataset
df = pd.read_csv('/content/sample_sales_performance_raw.csv')
display(df.head(5))
# Out:
#      OrderID   OrderDate Quantity  UnitPrice TotalPrice  Discount_Applied  \
# 0     850597  06/05/2024        3  $1,956.20  $5,868.60              0.00
# 1     868855  27/07/2024        4    $514.55  $1,749.47               NaN
# 2  ORD-49270  14/01/2024        1    $524.54    $445.86              0.15
# 3     880801  03/03/2024        2  $2,202.28  $3,490.10              0.15
# 4     850411  25/06/2023        2     $86.48    $155.66              0.10
#
#    PaymentMethod                             ProductID  \
# 0    Credit Card  ad305847-e2ad-42e9-b5d8-2d748588b0d9
# 1  Bank Transfer  934cf22c-9564-4318-a081-33ada53a7c32
# 2         Crypto  a561200a-f638-4e09-a216-1873df420b66
# 3    Credit Card  9338c8f2-dcd0-47c2-8b6c-c94dcb0bc7f8
# 4    Credit Card  a561200a-f638-4e09-a216-1873df420b66
#
#                           ProductName  ProductCategory  ...        Region  \
# 0      Iterate Front-End Web Services        Furniture  ...  Asia-Pacific
# ...

# %% [markdown]
# ### **A. Data Cleaning and Preprocessing (Pandas & Core Python)**
# 1.  Identifying all columns with missing values and calculate the percentage of missing data for each. Devise and implement a strategy to handle the NaNs in `SalesRepID`, `CustomerID`, and `LeadSource`.

# %%
# Write your code here
# Finding the length of the df
print(f'Length of the df:{len(df)}')
# Identifying the columns with missing values
print('----------')
print(df.isna().sum())
print('----------')
# Calculating the percentage of missing data
print((df.isna().sum()/len(df))*100)
# Out:
# Length of the df:1000
# ----------
# OrderID                0
# OrderDate              0
# Quantity               5
# UnitPrice              0
# TotalPrice             0
# Discount_Applied      50
# PaymentMethod          0
# ProductID              0
# ProductName            0
# ProductCategory        0
# SKU                    0
# CustomerID            80
# CustomerName           0
# CustomerEmail          0
# CustomerPhone          0
# BillingAddress         0
# ShippingCity           0
# ShippingState          0
# ShippingCountry        0
# SalesRepID           232
# SalesRepName         232
# Region               149
# SalesChannel           0
# LeadSource             0
# OrderStatus            0
# ShippingDate           0
# ShippingMethod         0
# WarehouseCode          0
# Notes                902
# COGS_Percentage        0
# Lead_Source         1000
# dtype: int64
# ----------
# OrderID               0.0
# OrderDate             0.0
# Quantity              0.5
# ...

# %%
# Handling the NaNs in SalesRepId, CustomerID and LeadSource
# Since the LeadSource has no data, it is best to dropped
df.drop('Lead_Source', axis=1, inplace=True, errors='ignore')
print(df.columns)
# Replacing the Nan values for SalesRepId and Customer ID
df['SalesRepID'].fillna('Unknown-Rep', inplace=True)
df['CustomerID'].fillna('Unknown-Cust', inplace=True)
# Out:
# Index(['OrderID', 'OrderDate', 'Quantity', 'UnitPrice', 'TotalPrice',
#        'Discount_Applied', 'PaymentMethod', 'ProductID', 'ProductName',
#        'ProductCategory', 'SKU', 'CustomerID', 'CustomerName', 'CustomerEmail',
#        'CustomerPhone', 'BillingAddress', 'ShippingCity', 'ShippingState',
#        'ShippingCountry', 'SalesRepID', 'SalesRepName', 'Region',
#        'SalesChannel', 'LeadSource', 'OrderStatus', 'ShippingDate',
#        'ShippingMethod', 'WarehouseCode', 'Notes', 'COGS_Percentage'],
#       dtype='object')

# %% [markdown]
# 2.  The `UnitPrice` and `TotalPrice` columns are stored as strings. Converting them.

# %%
# Removing the symbols: '$' and ','
df['UnitPrice'] = df['UnitPrice'].str.replace(r'[/$,]', '', regex=True)
df['TotalPrice'] = df['TotalPrice'].str.replace(r'[/$,]', '', regex=True)
# Checking for the values
print(df[['UnitPrice','TotalPrice']].head(5))
# Converting the values to numeric type
df['UnitPrice'] = pd.to_numeric(df['UnitPrice'])
df['TotalPrice'] = pd.to_numeric(df['TotalPrice'])
# Converting the values to float value
df['UnitPrice'] = df['UnitPrice'].astype(float)
df['TotalPrice'] = df['TotalPrice'].astype(float)
# Checking the datatypes
print(df[['UnitPrice','TotalPrice']].dtypes)
# Out:
#   UnitPrice TotalPrice
# 0   1956.20    5868.60
# 1    514.55    1749.47
# 2    524.54     445.86
# 3   2202.28    3490.10
# 4     86.48     155.66
# UnitPrice     float64
# TotalPrice    float64
# dtype: object

# %% [markdown]
# 3.  The `Quantity` column contains non-numeric text. Cleaning this column by replacing text with their numeric counterparts (e.g., 'One' -> 1) and handling 'N/A' values (e.g., replacing with the median quantity).

# %%
# Checking the values
print(df['Quantity'].unique())
# Out:
# ['3' '4' '1' '2' '94' '10' '5' 'One' '729' 'Three' nan '77' '62' '89'
#  '670' 'Two' '61' '85' '553' '776' '64' '718']

# %%
# Converting the values: 'one -> 1', 'Two -> 2','Three -> 3'
df['Quantity']=df['Quantity'].replace({'One':1,'Two':2,'Three':3})
# Replacing the Nan values with median quantity
median_nan = df['Quantity'].median()
# Converting the value to integer
print(median_nan)
df['Quantity'].fillna(df['Quantity'].median(), inplace=True)
print(df['Quantity'].unique())
# Out:
# 2.0
# ['3' '4' '1' '2' '94' '10' '5' 1 '729' 3 np.float64(2.0) '77' '62' '89'
#  '670' '61' '85' '553' '776' '64' '718']

# %% [markdown]
# 4.  Standardizing the `Region` and `ProductCategory` columns to have consistent, clean values.

# %%
# Checking the values Region and ProductCategory
print(df['Region'].unique())
print(df['ProductCategory'].unique())
# Out:
# ['Asia-Pacific' 'APAC' 'N. America' 'EMEA' nan
#  'Europe, Middle East, Africa' 'North America']
# ['Furniture' 'electronics' 'office_supplies' 'Software' 'ELEC'
#  'Office Supplies' 'Electronics']

# %%
# Checking is there any null values
print(df['Region'].isnull().sum())
print(df['ProductCategory'].isnull().sum())
# Out:
# 149
# 0

# %%
# Replacing the null values in the region column
df['Region'].fillna('Unknown', inplace=True)
# Replacing the values and standardizing
df['Region']=df['Region'].replace({'N. America':'North America','APAC':'Asia-Pacific','EMEA':'Europe, Middle East, Africa'})
df['ProductCategory']=df['ProductCategory'].replace({'ELEC':'Electronics'})
print(df['Region'].unique())
print(df['ProductCategory'].unique())
# Out:
# ['Asia-Pacific' 'North America' 'Europe, Middle East, Africa' 'Unknown']
# ['Furniture' 'electronics' 'office_supplies' 'Software' 'Electronics'
#  'Office Supplies']

# %% [markdown]
# 5.  Identifying and correcting all records where the `ShippingDate` is earlier than the `OrderDate`.

# %%
# Checking the data types of the shippingdate and orderdate
print(df[['OrderDate','ShippingDate']].dtypes)
# Out:
# OrderDate       object
# ShippingDate    object
# dtype: object

# %%
# Changing the data types
df['OrderDate'] = pd.to_datetime(df['OrderDate'], dayfirst=True)
df['ShippingDate'] = pd.to_datetime(df['ShippingDate'], dayfirst=True)
print(df[['OrderDate','ShippingDate']].dtypes)
# Out:
# OrderDate       datetime64[ns]
# ShippingDate    datetime64[ns]
# dtype: object

# %%
# counting the no.of.records
earlier_date = df[df['ShippingDate'] < df['OrderDate']]
print(len(earlier_date))
# Out:
# 20

# %%
# Changing the records of shippingdate to orderdate
df.loc[earlier_date.index, 'ShippingDate'] = df.loc[earlier_date.index, 'OrderDate']

# %% [markdown]
# 6.  Creating a new column called `Calculated_TotalPrice`. The formula should be `Quantity * UnitPrice * (1 - Discount_Applied)`.

# %%
# Checking for the datatypes
print(df[['Quantity','UnitPrice','Discount_Applied']].dtypes)
# Out:
# Quantity             object
# UnitPrice           float64
# Discount_Applied    float64
# dtype: object

# %%
# Converting the datatypes of quantity and unitprice
print(df['Quantity'].unique())
print(df['UnitPrice'].unique())
print(df['Discount_Applied'].unique())
# Out:
# ['3' '4' '1' '2' '94' '10' '5' 1 '729' 3 np.float64(2.0) '77' '62' '89'
#  '670' '61' '85' '553' '776' '64' '718']
# [1956.2   514.55  524.54 2202.28   86.48  395.28  360.54 2154.04 2132.6
#  1095.26  821.57  477.62 1308.45  105.56 1796.14 1520.84   86.11 1191.36
#  1326.67  283.42  515.77 2253.02 1091.87  358.24 1160.86 1141.03 1635.85
#   148.33 2437.14  961.31  806.64  256.76 1201.32  720.15  962.85 2073.27
#  1193.52 2332.9   992.74   43.93  906.63 1864.88 2183.   1119.89  890.95
#   914.42 2091.17 1749.97 1507.99  813.68  671.09  612.96 1328.97 1104.72
#  1898.79 1831.13 1066.66 1168.41 1233.49  929.63  525.04 1219.61 1338.04
#  2280.26 1467.6  2333.25 1285.98  273.86 1810.95 1828.5  1281.22  333.08
#  2139.27 1985.43  934.15 1525.9   551.96  546.06 2028.96 1579.46 1495.53
#  1681.91  163.17   44.58 1958.08  271.   1949.26 2207.57 2409.92  835.41
#   531.57 1148.13 2320.7  1001.69 1706.58 2068.68 1684.96  197.78 1068.03
# ...

# %%
# Replacing the values
df['Quantity']=df['Quantity'].replace({'One':1,'Two':2,'Three':3,'nan':0})
df['UnitPrice']=df['UnitPrice'].replace(r'[\$,]', '', regex=True)
df['Discount_Applied']=df['Discount_Applied'].replace({'nan':0})

# %%
df['Quantity'] = df['Quantity'].astype(float)
df['UnitPrice'] = df['UnitPrice'].astype(float)
# Now creating the calculated_totalprice
df['Calculated_TotalPrice'] = df['Quantity'] * df['UnitPrice'] * (1 - df['Discount_Applied'])
print(df['Calculated_TotalPrice'].head(5))
# Out:
# 0    5868.600
# 1         NaN
# 2     445.859
# 3    3743.876
# 4     155.664
# Name: Calculated_TotalPrice, dtype: float64

# %% [markdown]
# 7.  Creating another column `Price_Discrepancy` that shows the difference between the original `TotalPrice` and  new `Calculated_TotalPrice`.

# %%
# Write your code here
# Creating Pric_Discrepancy column
# Checking the data types
print(df['TotalPrice'].dtypes)
# Out:
# float64

# %%
# Converting the data type
df['TotalPrice'] = df['TotalPrice'].replace(r'[\$,]', '', regex=True)
df['TotalPrice'] = pd.to_numeric(df['TotalPrice'])
print(df['TotalPrice'].astype(float))
# Out:
# 0      5868.60
# 1      1749.47
# 2       445.86
# 3      3490.10
# 4       155.66
#         ...
# 995    2853.20
# 996     104.41
# 997    4208.08
# 998    1336.05
# 999    6745.20
# Name: TotalPrice, Length: 1000, dtype: float64

# %%
df['Price_Discrepancy'] = df['TotalPrice'] - df['Calculated_TotalPrice']
print(df['Price_Discrepancy'].round(2))
# Out:
# 0         0.00
# 1          NaN
# 2         0.00
# 3      -253.78
# 4        -0.00
#         ...
# 995       0.00
# 996      -7.59
# 997    3156.06
# 998       0.00
# 999      -0.00
# Name: Price_Discrepancy, Length: 1000, dtype: float64

# %% [markdown]
# 8.  Ensuring all date columns (`OrderDate`, `ShippingDate`) are converted to the proper datetime format.

# %%
# Converting the data types
print(df['OrderDate'].dtype)
# Out:
# datetime64[ns]

# %%
# Converting the data types
df['OrderDate'] = pd.to_datetime(df['OrderDate'], dayfirst=True)
df['ShippingDate'] = pd.to_datetime(df['ShippingDate'], dayfirst=True)
print(df[['OrderDate','ShippingDate']].dtypes)
# Out:
# OrderDate       datetime64[ns]
# ShippingDate    datetime64[ns]
# dtype: object

# %% [markdown]
# ### **B. Exploratory Data Analysis (EDA) (Pandas, Matplotlib & Seaborn)**
# 9.  Finding what is the total revenue over the three-year period? (Use your `Calculated_TotalPrice` and filter for valid `OrderStatus`).

# %%
# Checking for the data present in the orderstatus column
print(df['OrderStatus'].unique())
# Taking shipped and pending into consideration
valid_status = ['Shipped', 'Pending']
df_valid = df[df['OrderStatus'].isin(valid_status)]
total_revenue = df_valid['Calculated_TotalPrice'].sum()
print(total_revenue)
# Out:
# ['Cancelled' 'Returned' 'Shipped' 'Pending']
# 1774320.031

# %% [markdown]
# 10. Plotting the total monthly revenue over time.

# %%
monthly_rev = df_valid.resample('M', on='OrderDate')['Calculated_TotalPrice'].sum().reset_index()
monthly_rev = df_valid.resample('M', on='OrderDate')['Calculated_TotalPrice'].sum().reset_index()

# Plotting
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_rev, x='OrderDate', y='Calculated_TotalPrice', marker='o')
plt.title('3-Year Monthly Revenue Trend')
plt.xlabel('Date')
plt.ylabel('Total Revenue ($)')
plt.show()
# No constant rate

# %% [markdown]
# 11. Finding which are the top 10 `ProductName`s by total revenue?

# %%
top_products = df_valid.groupby('ProductName')['Calculated_TotalPrice'].sum().nlargest(10).reset_index()
print(top_products)
# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=top_products, x='Calculated_TotalPrice', y='ProductName')
plt.title('Top 10 Products by Total Revenue')
plt.xlabel('Total Revenue')
plt.ylabel('Product Name')
plt.show()
# Out:
#                              ProductName  Calculated_TotalPrice
# 0         Empower Mission-Critical Users            402831.7782
# 1         Iterate Front-End Web Services            231966.4775
# 2           Integrate Synergistic Models            181787.6543
# 3           Incentivize Dynamic Channels            181302.7735
# 4          Visualize Killer Deliverables            176552.6625
# 5     Expedite Distributed Relationships            163470.7485
# 6              Evolve Granular Mindshare            118302.2195
# 7  Re-Intermediate Proactive Communities            115069.3960
# 8            Extend End-To-End Synergies            112522.0655
# 9     Productize Collaborative E-Markets             90514.2555

# %% [markdown]
# 12. Creating a bar chart showing the total revenue for each `Region`. Which region is the top performer?

# %%
region_revenue = df_valid.groupby('Region')['Calculated_TotalPrice'].sum().reset_index()
# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(data=region_revenue, x='Region', y='Calculated_TotalPrice')
plt.title('Total Revenue by Region')
plt.xlabel('Region')
plt.ylabel('Total Revenue')
plt.show()
# Europe, Middle east and Africa is the top performer

# %% [markdown]
# 13. Finding how is revenue distributed across different `SalesChannel`s?

# %%
channel_revenue = df_valid.groupby('SalesChannel')['Calculated_TotalPrice'].sum().reset_index()
# Plotting
plt.figure(figsize=(8, 8))
plt.pie(channel_revenue['Calculated_TotalPrice'],
        labels=channel_revenue['SalesChannel'],
        autopct='%1.1f%%',
        startangle=140,
        colors=sns.color_palette('Set2'))
plt.title('Total Revenue Distribution by Sales Channel', fontsize=14)
plt.axis('equal') # Ensures the pie is a perfect circle
plt.show()

# %% [markdown]
# 14. Finding what is the distribution of `Discount_Applied`?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_valid['Discount_Applied'], bins=20, kde=True, color='teal')
plt.title('Distribution of Discounts Applied')
plt.xlabel('Discount Percentage (0.1 = 10%)')
plt.ylabel('Number of Orders', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Discounts are not that much common.

# %% [markdown]
# 15. Comparing the average `Quantity` per order for each `ProductCategory` using a bar chart.

# %%
avg_qty_per_cat = df_valid.groupby('ProductCategory')['Quantity'].mean().sort_values(ascending=False).reset_index()

# Plotting the Bar Chart
plt.figure(figsize=(10, 6))
sns.barplot(data=avg_qty_per_cat, x='Quantity', y='ProductCategory', palette='coolwarm')
plt.title('Average Quantity per Order by Product Category', fontsize=14)
plt.xlabel('Average Quantity Sold', fontsize=12)
plt.ylabel('Product Category', fontsize=12)
plt.show()

# %% [markdown]
# 16. Using a heatmap to visualize the correlation between numerical columns like `Quantity`, `UnitPrice`, `Discount_Applied`, and `COGS_Percentage`.

# %%
corr_columns = ['Quantity', 'UnitPrice', 'Discount_Applied', 'COGS_Percentage']

# Calculate the correlation matrix
correlation = df_valid[corr_columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='RdBu', center=0, fmt='.2f')
plt.title('Correlation Heatmap: Sales Metrics', fontsize=16)
plt.show()

# %% [markdown]
# ### **C. Feature Engineering (Pandas & NumPy)**
# 17. Creating a `Profit` column by calculating `Calculated_TotalPrice * (1 - COGS_Percentage)`.

# %%
# Checking for the COGS_Percentage data type
print(df['COGS_Percentage'].dtypes)
# Out:
# float64

# %%
# Creating the profit column
df['Profit'] = df['Calculated_TotalPrice'] * (1 - df['COGS_Percentage'])
print(df['Profit'].head(5))
# Out:
# 0    1701.89400
# 1           NaN
# 2     178.34360
# 3    1085.72404
# 4      59.15232
# Name: Profit, dtype: float64

# %% [markdown]
# 18. Engineering a `Shipping_Time_Days` column by calculating the difference between `ShippingDate` and `OrderDate`.

# %%
df['Shipping_Time_Days'] = (df['ShippingDate'] - df['OrderDate']).dt.days
print(df['Shipping_Time_Days'].head(5))
# Out:
# 0    6
# 1    2
# 2    5
# 3    3
# 4    3
# Name: Shipping_Time_Days, dtype: int64

# %% [markdown]
# 19. Creating `Order_Year`, `Order_Month`, and `Order_Day_of_Week` columns from the `OrderDate`.

# %%
# Year
df['Order_Year'] = df['OrderDate'].dt.year
# Month
df['Order_Month'] = df['OrderDate'].dt.month
# Day
df['Order_Day_of_Week'] = df['OrderDate'].dt.day_name()
print(df[['Order_Year','Order_Month','Order_Day_of_Week']].head(5))
# Out:
#    Order_Year  Order_Month Order_Day_of_Week
# 0        2024            5            Monday
# 1        2024            7          Saturday
# 2        2024            1            Sunday
# 3        2024            3            Sunday
# 4        2023            6            Sunday

# %% [markdown]
# 20. Creating a boolean column `Is_Discounted` which is `True` if `Discount_Applied` > 0 and `False` otherwise.

# %%
df['Is_Discounted'] = df['Discount_Applied'] > 0
print(df['Is_Discounted'].head(5))
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# Name: Is_Discounted, dtype: bool

# %% [markdown]
# 21. Engineering a `Revenue_per_Unit` column (`Calculated_TotalPrice / Quantity`).

# %%
df['Revenue_per_Unit'] = df['Calculated_TotalPrice'] / df['Quantity']
print(df['Revenue_per_Unit'].head(5))
# Out:
# 0    1956.200
# 1         NaN
# 2     445.859
# 3    1871.938
# 4      77.832
# Name: Revenue_per_Unit, dtype: float64

# %% [markdown]
# ### **D. Advanced Analysis & Business Insights**
# 22. Finding who are the top 10 `SalesRepName`s by total `Profit` generated?

# %%
top_salesreps = df.groupby('SalesRepName')['Profit'].sum().nlargest(10).reset_index()
print(top_salesreps)
# Out:
#      SalesRepName         Profit
# 0    Kayla Hughes  651368.948829
# 1  Robert Mcmahon  373935.509037

# %% [markdown]
# 23. Analyzing the performance of each `LeadSource`. Create a summary table that shows the total revenue, average deal size, and number of orders for each source. Which source is the most valuable?

# %%
lead_source_analysis = df_valid.groupby('LeadSource').agg(
    Total_Revenue=('Calculated_TotalPrice', 'sum'),
    Avg_Deal_Size=('Calculated_TotalPrice', 'mean'),
    Order_Count=('OrderID', 'count')
).reset_index()
lead_source_analysis = lead_source_analysis.sort_values(by='Total_Revenue', ascending=False)
print(lead_source_analysis)
# Out:
#    LeadSource  Total_Revenue  Avg_Deal_Size  Order_Count
# 4         Web    500986.6968    4960.264325          108
# 0   Cold Call    498662.4772    4986.624772          108
# 1     Organic    296352.7495    2769.651864          115
# 2    Referral    286410.2600    2727.716762          112
# 3  Trade Show    191907.8475    2231.486599           87

# %% [markdown]
# 24. Finding how does applying a discount affect the `Quantity` sold? Comparing the average quantity for orders with and without discounts.

# %%
# Create a label to distinguish between discounted and full-price orders
df_valid['Is_Discounted'] = df_valid['Discount_Applied'] > 0
discount_effect = df_valid.groupby('Is_Discounted')['Quantity'].mean().reset_index()
discount_effect['Is_Discounted'] = discount_effect['Is_Discounted'].map({True: 'Discount Applied', False: 'No Discount'})
# Plotting
plt.figure(figsize=(8, 6))
sns.barplot(data=discount_effect, x='Is_Discounted', y='Quantity', palette='viridis')
plt.title('Average Quantity Sold: Discounted vs. Full Price')
plt.ylabel('Average Quantity per Order')
plt.xlabel('')
plt.show()
print(discount_effect)
# Out:
#       Is_Discounted   Quantity
# 0       No Discount   2.401254
# 1  Discount Applied  12.549763

# %% [markdown]
# 25. Finding what is the return rate (`OrderStatus` == 'Returned') for each `ProductCategory`? Are some categories more prone to returns?

# %%
df['p_orderstatus'] = (df['OrderStatus'] == 'Returned')
print(df.groupby('ProductCategory')['p_orderstatus'].sum())
# Electronics items are more prone to returns compared to other categories
# Out:
# ProductCategory
# Electronics        59
# Furniture          31
# Office Supplies    35
# Software           39
# electronics        36
# office_supplies    31
# Name: p_orderstatus, dtype: int64

# %% [markdown]
# 26. Analyzing the sales performance by `Region` and `SalesChannel`. Creating a grouped bar chart to show the revenue of each channel within each region. Where are the biggest opportunities?

# %%
region_performance = df_valid.groupby(['Region', 'SalesChannel'])['Calculated_TotalPrice'].sum().reset_index()
region_performance.rename(columns={'Calculated_TotalPrice': 'Revenue'}, inplace=True)
# Create a Grouped Bar Chart
plt.figure(figsize=(12, 6))
sns.barplot(data=region_performance, x='Region', y='Revenue', hue='SalesChannel')
plt.title('Revenue Performance by Region and Sales Channel', fontsize=15)
plt.ylabel('Total Revenue ($)')
plt.show()
print(region_performance)
# Out:
#                          Region SalesChannel      Revenue
# 0                  Asia-Pacific       Direct   83140.1220
# 1                  Asia-Pacific       Online   72970.1500
# 2                  Asia-Pacific      Partner  119305.2510
# 3                  Asia-Pacific     Reseller   90161.6650
# 4   Europe, Middle East, Africa       Direct  114163.9775
# 5   Europe, Middle East, Africa       Online  239233.0060
# 6   Europe, Middle East, Africa      Partner   91609.0420
# 7   Europe, Middle East, Africa     Reseller  316127.7122
# 8                 North America       Direct  103971.6765
# 9                 North America       Online   80555.3420
# 10                North America      Partner  109871.8975
# 11                North America     Reseller   73575.1690
# 12                      Unknown       Direct  123351.3188
# 13                      Unknown       Online   40913.2045
# 14                      Unknown      Partner   51464.1755
# ...

# %% [markdown]
# 27. Finding what is the average `Shipping_Time_Days` for each `ShippingMethod`? Is the 'Express' method significantly faster?

# %%
# Printing the columns
print(df.columns)
# Out:
# Index(['OrderID', 'OrderDate', 'Quantity', 'UnitPrice', 'TotalPrice',
#        'Discount_Applied', 'PaymentMethod', 'ProductID', 'ProductName',
#        'ProductCategory', 'SKU', 'CustomerID', 'CustomerName', 'CustomerEmail',
#        'CustomerPhone', 'BillingAddress', 'ShippingCity', 'ShippingState',
#        'ShippingCountry', 'SalesRepID', 'SalesRepName', 'Region',
#        'SalesChannel', 'LeadSource', 'OrderStatus', 'ShippingDate',
#        'ShippingMethod', 'WarehouseCode', 'Notes', 'COGS_Percentage',
#        'Calculated_TotalPrice', 'Price_Discrepancy', 'Profit',
#        'Shipping_Time_Days', 'Order_Year', 'Order_Month', 'Order_Day_of_Week',
#        'Is_Discounted', 'Revenue_per_Unit', 'p_orderstatus'],
#       dtype='object')

# %%
# Average Shipping_Time_Days
avg_shipping_time = df.groupby('ShippingMethod')['Shipping_Time_Days'].mean().reset_index()
print(avg_shipping_time)
# Plotting
plt.figure(figsize=(10, 5))
sns.barplot(data=avg_shipping_time, x='ShippingMethod', y='Shipping_Time_Days', palette='coolwarm')
plt.title('Average Delivery Time by Shipping Method')
plt.ylabel('Average Days to Ship')
plt.xlabel('Shipping Method')
plt.show()
print(avg_shipping_time)
# From the graph it is evident that express is not much faster compared to overnight and standard
# Out:
#   ShippingMethod  Shipping_Time_Days
# 0        Express            7.362637
# 1      Overnight            7.397260
# 2       Standard            7.526163
#   ShippingMethod  Shipping_Time_Days
# 0        Express            7.362637
# 1      Overnight            7.397260
# 2       Standard            7.526163

# %% [markdown]
# 28. Identifying the top 5 customers (`CustomerName`) by total lifetime profit. What are their characteristics (e.g., common region, product categories)?

# %%
top_customers = df.groupby(['CustomerName','Region','ProductCategory'])['Profit'].sum().nlargest(5).reset_index()
print(top_customers)
# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(data=top_customers, x='CustomerName', y='Profit', hue='ProductCategory')
plt.title('Top 5 Most Profitable Customer-Category Combinations', fontsize=15)
plt.ylabel('Total Profit ($)')
plt.xlabel('Customer Name')
plt.xticks(rotation=45) # Rotates names so they don't overlap
plt.legend(title='Product Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
#                     CustomerName                       Region  \
# 0                    Hensley LLC  Europe, Middle East, Africa
# 1  Kaufman, Goodman and Williams                North America
# 2                       Rowe Ltd  Europe, Middle East, Africa
# 3    Jones, Rodgers and Martinez  Europe, Middle East, Africa
# 4                     Deleon LLC                 Asia-Pacific
#
#    ProductCategory        Profit
# 0  office_supplies  94229.359656
# 1      electronics  90454.214728
# 2      Electronics  54570.527030
# 3      Electronics  50963.550440
# 4         Software  49776.969000

# %% [markdown]
# 29. Finding does the `PaymentMethod` have any correlation with the `TotalPrice` of an order?

# %%
# Plotting
plt.figure(figsize=(12, 6))
sns.boxplot(data=df_valid, x='PaymentMethod', y='Calculated_TotalPrice', palette='Set3')
plt.title('Comparison of Order Totals by Payment Method', fontsize=15)
plt.xlabel('Payment Method')
plt.ylabel('Total Price ($)')
plt.show()

# %% [markdown]
# 30. Synthesizing all the findings.

# %%
# 1. Must focus on top customers who generated lifetime profit (Hensley LLC,Kaufman, Goodman and Williams, Rowe Ltd,Jones, Rodgers and Martinez, Deleon LLC, inorder to loss them as they are a big deal.
# 2. More marketing must be done in Europe, middle east and africa where the majority of customers are concentrated.
# 3. Need to investigate the region (asia pacific and north america) where the sales had dropped and allocate more resources to improve them.
# 4. Customers who spend more on credit card must be given more discounts and let them stay on same payment type.
# 5. Categories with high return rates must to constantly subjected to quality check.
# 6. Inventory must be increased for the products: Empower Mission-Critical Users, Iterate Front-End Web Services, Integrate Synergistic Models, Incentivize Dynamic Channels, Visualize Killer Deliverables, Expedite Distributed Relationships which are sold more.
# 7. Stop offering discounts on products where the quantity sold doesn't actually increase when the price drops.
